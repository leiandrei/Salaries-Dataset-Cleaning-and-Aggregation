# %% [markdown]
# ### Salaries Dataset Cleaning and Aggregation

# %% [markdown]
# ##### This notebooks highlights case study analysis on salaries dataset gathered from Kaggle, and will be used to highlight:
# - Data Ingestion from SQLite
# - Data Cleaning Techniques
# - Data Aggregations and Pivot Tables
# - Exploratory Data Analysis (EDA)

# %%
# import necessary libraries
from typing import List, Dict
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv("../data/processed/clean_data.csv", index_col=0)
df.head()
# Out:
#        employee_name                                       job_title  \
# 0     Nathaniel Ford  General Manager-Metropolitan Transit Authority
# 1       Gary Jimenez                 Captain III (Police Department)
# 2     Albert Pardini                 Captain III (Police Department)
# 3  Christopher Chong            Wire Rope Cable Maintenance Mechanic
# 4    Patrick Gardner    Deputy Chief Of Department,(Fire Department)
#
#     base_pay  overtime_pay  other_pay  benefits  total_pay  \
# 0  167411.18          0.00  400184.25       0.0  567595.43
# 1  155966.02     245131.88  137811.38       0.0  538909.28
# 2  212739.13     106088.18   16452.60       0.0  335279.91
# 3   77916.00      56120.71  198306.90       0.0  332343.61
# 4  134401.60       9737.00  182234.59       0.0  326373.19
#
#    total_pay_benefits  year         agency         status
# 0           567595.43  2011  San Francisco  Not Specified
# 1           538909.28  2011  San Francisco  Not Specified
# ...

# %%
# quick assessment on newly cleaned data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147333 entries, 0 to 148620
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   employee_name       147333 non-null  object
#  1   job_title           147333 non-null  object
#  2   base_pay            147307 non-null  float64
#  3   overtime_pay        147333 non-null  float64
#  4   other_pay           147333 non-null  float64
#  5   benefits            147333 non-null  float64
#  6   total_pay           147333 non-null  float64
#  7   total_pay_benefits  147333 non-null  float64
#  8   year                147333 non-null  int64
#  9   agency              147333 non-null  object
#  10  status              147333 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 13.5+ MB

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# function to create Aggregation Tables
def agg_tables(df: pd.DataFrame, grp_key: List[str], aggfunc: Dict[str, str]) -> pd.DataFrame:

    if df.empty:
        raise ValueError("The DataFrame is empty")
    
    return df.groupby(grp_key).agg(aggfunc).reset_index()


# function to create Piv Tables
def piv_tables(df: pd.DataFrame, idx: List[str], cols: List[str], aggfunc: List[str] | None, values: List[str]) -> pd.pivot_table:

    if df.empty:
        raise ValueError("The DataFrame is empty")
    
    return df.pivot_table(index=idx, values=values, columns=cols, aggfunc=aggfunc | None)
