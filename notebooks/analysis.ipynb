# %% [markdown]
# ### Salaries Dataset Cleaning and Aggregation

# %% [markdown]
# ##### This notebooks highlights case study analysis on salaries dataset gathered from Kaggle, and will be used to highlight:
# - Data Ingestion from SQLite
# - Data Cleaning Techniques
# - Data Aggregations and Pivot Tables
# - Exploratory Data Analysis (EDA)

# %%
# import necessary libraries
from typing import List, Dict
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df = pd.read_csv("../data/processed/clean_data.csv", index_col=0)
df.head()
# Out:
#        employee_name                                       job_title  \
# 0     Nathaniel Ford  General Manager-Metropolitan Transit Authority
# 1       Gary Jimenez                 Captain III (Police Department)
# 2     Albert Pardini                 Captain III (Police Department)
# 3  Christopher Chong            Wire Rope Cable Maintenance Mechanic
# 4    Patrick Gardner     Deputy Chief Of Department(Fire Department)
#
#     base_pay  overtime_pay  other_pay  benefits  total_pay  \
# 0  167411.18          0.00  400184.25       0.0  567595.43
# 1  155966.02     245131.88  137811.38       0.0  538909.28
# 2  212739.13     106088.18   16452.60       0.0  335279.91
# 3   77916.00      56120.71  198306.90       0.0  332343.61
# 4  134401.60       9737.00  182234.59       0.0  326373.19
#
#    total_pay_benefits  year         agency         status
# 0           567595.43  2011  San Francisco  Not Specified
# 1           538909.28  2011  San Francisco  Not Specified
# ...

# %%
# quick assessment on newly cleaned data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147333 entries, 0 to 148620
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   employee_name       147333 non-null  object
#  1   job_title           147333 non-null  object
#  2   base_pay            147307 non-null  float64
#  3   overtime_pay        147333 non-null  float64
#  4   other_pay           147333 non-null  float64
#  5   benefits            147333 non-null  float64
#  6   total_pay           147333 non-null  float64
#  7   total_pay_benefits  147333 non-null  float64
#  8   year                147333 non-null  int64
#  9   agency              147333 non-null  object
#  10  status              147333 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 13.5+ MB

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Transit Operator                         9304
# Special Nurse                            5753
# Registered Nurse                         4904
# Custodian                                3190
# Police Officer III                       3145
#                                          ...
# Chief Of Department (Fire Department)       1
# Deputy Director Of Investments              1
# Marina Associate Manager                    1
# Sr Cnselor Juv Hall (Sfers)                 1
# Forensic Toxicologist Supervis              1
# Name: count, Length: 1629, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Distribution of Numerical Values

# %%
columns = ["base_pay", "overtime_pay", "other_pay", "benefits", "total_pay", "total_pay_benefits"]

fig, ax = plt.subplots(2, 3, figsize=(12, 10))

ax = ax.flatten()

for i, cols in enumerate(columns):
    sns.histplot(data=df, x=df[cols], ax=ax[i], bins=10)
    sns.despine(top=True, right=True)
    ax[i].grid(True, alpha=0.6)

# %% [markdown]
# #### Correlation Across Numerical Values

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='magma')
plt.title("Correlation Matrix on Numerical Values")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix on Numerical Values')

# %%
# time series of base pay through out the years
time_series = df.groupby('year')['base_pay'].median()

fig, ax = plt.subplots()

ax.plot(time_series.index, time_series.values, marker='o', linestyle='--')
ax.set_xticks(time_series.index)
ax.set_title("Median Base Pay Across the Years")
ax.set_ylabel("Median Base Pay")
ax.set_xlabel("Year")
ax.grid(True, alpha=0.3)
sns.despine(top=True, right=True)

# %% [markdown]
# #### Handling Outliers in Numerical Values

# %%
# get the iqr and upper and lower bound thresholds
cols = ['base_pay', 'overtime_pay', 'other_pay', 'benefits', 'total_pay', 'total_pay_benefits']

q1 = df[cols].quantile(0.25)
q3 = df[cols].quantile(0.75)
iqr = q3 - q1

thresholds = pd.DataFrame({
    'Q1 (25%)': q1,
    'Q3 (75%)': q3,
    'IQR': iqr,
    'Lower Bound': q1 - 1.5 * iqr,
    'Upper Bound': q3 + 1.5 * iqr
})

thresholds.round(2)
# Out:
#                     Q1 (25%)   Q3 (75%)       IQR  Lower Bound  Upper Bound
# base_pay            35471.38   94984.00  59512.62    -53797.54    184252.92
# overtime_pay            0.00    4732.66   4732.66     -7098.99     11831.65
# other_pay               0.00    4244.57   4244.57     -6366.86     10611.42
# benefits                0.00   33533.80  33533.80    -50300.70     83834.50
# total_pay           37966.29  106285.42  68319.13    -64512.41    208764.12
# total_pay_benefits  46143.84  133304.36  87160.52    -84596.94    264045.14

# %%
# subset values without outliers
no_outliers = df[((df[cols] > thresholds['Lower Bound']) & (df[cols] < thresholds['Upper Bound'])).all(axis=1)]
no_outliers
# Out:
#                  employee_name                          job_title   base_pay  \
# 361              Ghodsi Davary                 Nursing Supervisor  183040.00
# 376                 Mikail Ali  Commander III (Police Department)  182135.01
# 395               David Briggs                       Manager VIII  181522.51
# 479               Allen Turpin        Senior Physician Specialist  176050.04
# 529            Zhi Jiar Zhuang        Senior Physician Specialist  175345.82
# ...                        ...                                ...        ...
# 148613         Nanette M Lloyd                      Special Nurse      19.97
# 148616       Afakasi O Afakasi             Public Service Trainee      21.48
# 148617  Charles F Williams Iii                     Pool Lifeguard      17.26
# 148619           Ian V Cameron       Is Program Analyst-Assistant       6.04
# 148620         India C Sabater                  Recreation Leader      15.50
#
# ...

# %% [markdown]
# #### Distribution of Numerical Values without outliers

# %%
columns = ["base_pay", "overtime_pay", "other_pay", "benefits", "total_pay", "total_pay_benefits"]

fig, ax = plt.subplots(2, 3, figsize=(12, 10))

ax = ax.flatten()

for i, cols in enumerate(columns):
    sns.histplot(data=no_outliers, x=no_outliers[cols], ax=ax[i], bins=10)
    sns.despine(top=True, right=True)
    ax[i].grid(True, alpha=0.6)

# %%
police = no_outliers[no_outliers["job_title"].str.contains("Police")]
fire = no_outliers[no_outliers["job_title"].str.contains("Fire")]

# %%
sns.histplot(data=police, x='base_pay', kde=True, bins=20)
# Out:
# <Axes: xlabel='base_pay', ylabel='Count'>

# %%
sns.histplot(data=fire, x='base_pay', kde=True, bins=20)
# Out:
# <Axes: xlabel='base_pay', ylabel='Count'>

# %%
# subset police officers
police_officers = police[police["job_title"].str.contains("Police Officer")]

officers_q1 = police_officers["base_pay"].quantile(0.25)
officers_q2 = np.median(police_officers["base_pay"])
officers_q3 = police_officers["base_pay"].quantile(0.75)
officers_q4 = police_officers["base_pay"].max()

ranges = [0, officers_q1, officers_q2, officers_q3, officers_q4]
labels = ["Police Officer", "Police Officer I", "Police Officer II", "Police Officer III"]

police_officers["Base Pay Level"] = pd.cut(
    police_officers["base_pay"],
    labels=labels,
    bins=ranges
)

sns.countplot(
    x='year',
    data=police_officers,
    hue='Base Pay Level'
)
sns.despine(
    top=True,
    right=True
)
plt.grid(True, alpha=0.3)
plt.xlabel("Year")
plt.ylabel("Count")
plt.tick_params('x', length=0)
# Out:
# C:\Users\LEI\AppData\Local\Temp\ipykernel_24088\1242830802.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_officers["Base Pay Level"] = pd.cut(

# %%
fig, ax = plt.subplots()
ax = sns.boxplot(
    x='job_title',
    y='base_pay',
    data=police_officers,
    ax=ax
)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.tick_params('x', length=0)
ax.set_xlabel('Job Title')
ax.set_ylabel("Base Pay")
# Out:
# C:\Users\LEI\AppData\Local\Temp\ipykernel_24088\2567407059.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Text(0, 0.5, 'Base Pay')

# %%
# time series plot of median base pay of police vs fire dept
fig, ax = plt.subplots()

timeseries_police = police.groupby('year').agg({"base_pay" : "median"})
timeseries_fire = fire.groupby('year').agg({"base_pay" : "median"})

ax.plot(timeseries_police.index, timeseries_police.values, linestyle='--', marker='o')
ax.plot(timeseries_fire.index, timeseries_fire.values, linestyle='-.', marker='^')
sns.despine(top=True, right=True)
ax.grid(True, alpha=0.5)
ax.set_xticks(time_series.index)
ax.set_ylabel("Base Pay")
ax.set_xlabel("Year")
ax.set_title("Fire vs Police Department (Median Base Pay)")
ax.legend(["Police Dept", "Fire Dept"])
